# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn import svm
import numpy as np
from sklearn.datasets.samples_generator import make_blobs
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# Out:
# C:\Users\Álvaro\anaconda3.1\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv(r"C:\Users\Álvaro\Final-project\Data\data.csv")

# %%
df
# Out:
#              eventTime_ay        Date                              email  \
# 0     2020-05-09 10:19:12  2020-05-09  eduardoperez@seincomobiliario.com
# 1     2020-04-12 14:50:10  2020-04-12             alexvonder@hotmail.com
# 2     2020-11-08 18:09:23  2020-11-08                      Evo@gmail.com
# 3     2020-08-25 15:18:38  2020-08-25         cesardelacalle@grupoccs.es
# 4     2020-11-16 11:02:42  2020-11-16                 brsbrs02@gmail.com
# ...                   ...         ...                                ...
# 8057  2020-07-05 11:44:34  2020-07-05                     kk@hotmail.com
# 8058  2020-08-29 08:45:46  2020-08-29                    sarah@slyne.com
# 8059  2020-06-04 09:03:30  2020-06-04             saraculebras@gmail.com
# 8060  2020-09-30 16:03:25  2020-09-30               blancopris@gmail.com
# 8061  2020-09-12 07:44:00  2020-09-12             sharktvdavid@gmail.com
#
#            firstName           lastName                   Sub_Categoria  \
# 0            EDUARDO              PEREZ            disenador-de-muebles
# 1          Alexandra              Perez                          chofer
# 2             Juanjo               Akze                  fotoperiodista
# 3     cesar fernando  de la calle verde                        conserje
# 4              Bruno                 RS                     proyectista
# ...              ...                ...                             ...
# 8057           Santi              Mirlo  entrenador-o-monitor-deportivo
# 8058           Sarah              Slyne  entrenador-o-monitor-deportivo
# 8059            Sara     Culebras Yagüe  entrenador-o-monitor-deportivo
# 8060        Priscila             Abbona  entrenador-o-monitor-deportivo
# 8061           David     Jimenez Ortega  entrenador-o-monitor-deportivo
#
#                      campaign medium                                userId  \
# 0                         NaN    NaN  083e8b2f-af6a-46b4-a9b9-4f79c1a32cf1
# 1         01_España_Genéricas    ppc  0feedfe0-5452-434c-8a70-845fa3fd638a
# 2                 10430315940    cpc  18bb05eb-d592-4459-a682-f622afb7208c
# 3                 10430285424    cpc  328d85a1-28b3-493d-ad17-ab58e4567357
# 4                 10430285424    cpc  39d91a35-e406-462d-a7a5-7b2291ba8340
# ...                       ...    ...                                   ...
# 8057                      NaN    NaN  7a6ca821-1e99-4156-bb35-9d904828b26b
# 8058                      NaN    NaN  ab772667-56c1-4e2a-b938-ae6e4e3980e3
# 8059                      NaN    NaN  dc059f05-6e2a-4cb6-9436-826b38d87ce9
# 8060  RC_pillarpage_nurturing  email  e2af6a50-4e9e-42c0-a5fc-784141160d31
# 8061              10430285424    cpc  aa27f98a-4b31-45be-9cb0-f2d5566a978c
#
#              source  ...  time_diff_ay_ac  time_diff_ac_vg  time_diff_vg_ff  \
# 0               NaN  ...              NaN              NaN  0 days 00:00:03
# 1           adwords  ...              NaN              NaN  0 days 00:00:02
# 2           adwords  ...              NaN              NaN              NaN
# 3           adwords  ...              NaN              NaN              NaN
# 4           adwords  ...              NaN              NaN              NaN
# ...             ...  ...              ...              ...              ...
# 8057            NaN  ...              NaN              NaN  0 days 00:00:03
# 8058            NaN  ...              NaN              NaN              NaN
# 8059            NaN  ...              NaN              NaN  0 days 00:00:03
# 8060  hs_automation  ...              NaN              NaN  0 days 00:00:04
# 8061        adwords  ...              NaN              NaN  0 days 00:00:08
#
#       time_diff_ff_fd time_diff_fd_pm                     city     cityId  \
# 0                 NaN             NaN                Barcelona    1005424
# 1                 NaN             NaN                (not set)  (not set)
# 2                 NaN             NaN        Mollet del Valles    1005431
# 3                 NaN             NaN  Villanueva de la Canada    9049240
# 4                 NaN             NaN                 A Coruna    1005479
# ...               ...             ...                      ...        ...
# 8057              NaN             NaN    Castellon de la Plana    1005539
# 8058              NaN             NaN                  Seville    1005421
# 8059              NaN             NaN        Torrejon de Ardoz    1005496
# 8060              NaN             NaN                 Pamplona    1005503
# 8061  0 days 00:04:05             NaN                    Palma    1005517
#
#                    region  regionId sessions
# 0               Catalonia     20278      2.0
# 1        Balearic Islands     21387      6.0
# 2               Catalonia     20278      2.0
# 3                  Madrid   9047045      1.0
# 4                 Galicia     20280      1.0
# ...                   ...       ...      ...
# 8057  Valencian Community     21388      1.0
# 8058            Andalusia     20269      2.0
# 8059               Madrid   9047045      1.0
# 8060              Navarre   9047051      1.0
# 8061     Balearic Islands     20287      3.0
#
# [8062 rows x 106 columns]

# %%
data = df.sort_values(by = 'Date', ascending = True)

# %%
pd.set_option("display.max_columns", 200)
data
# Out:
#              eventTime_ay        Date                             email  \
# 2252  2020-03-19 17:14:56  2020-03-19          vem_desarrollo@gmail.com
# 7648  2020-03-19 18:45:53  2020-03-19           andresaje2206@gmail.com
# 6225  2020-03-19 22:57:58  2020-03-19        charrasalahdin24@gmail.com
# 5047  2020-03-19 22:31:09  2020-03-19          munozmichael01@gmail.com
# 5048  2020-03-19 22:29:34  2020-03-19          munozmichael02@gmail.com
# ...                   ...         ...                               ...
# 7183  2020-11-24 06:43:03  2020-11-24             esanquer@proditec.com
# 7678  2020-11-24 12:49:12  2020-11-24  antoniohernandezingles@gmail.com
# 2939  2020-11-24 09:18:37  2020-11-24             guilleguis@icloud.com
# 2187  2020-11-24 06:52:05  2020-11-24            mariacortelh@gmail.com
# 7021  2020-11-24 09:38:11  2020-11-24            jawad.2025@hotmail.com
#
#             firstName           lastName            Sub_Categoria  \
# 2252  Victor Emmanuel            Molinas                  oficina
# 7648     Carlos André             Farfán  articulos-para-el-hogar
# 6225         Salahdin              Chara            bar-cafeteria
# 5047          Michael              Muñoz              restaurante
# 5048          Michael              Muñoz              restaurante
# ...               ...                ...                      ...
# 7183             Eric            Sanquer           tienda-deporte
# 7678          Antonio          Hernandez  yoga-pilates-instructor
# 2939        Guillermo       Guíjar Abril                  oficina
# 2187            María             Cortel                  oficina
# 7021           jaouad  tommouhi kaddouri            bar-cafeteria
#
#                                                campaign medium  \
# 2252  ES - Gen - Seguro Locales / local comercial / ...    ppc
# 7648  ES - Gen - Seguro Locales / local comercial / ...    ppc
# 6225              ES - Gen - Verticales - Seguros Bares    ppc
# 5047                                                NaN    NaN
# 5048                                                NaN    NaN
# ...                                                 ...    ...
# 7183                                        10430315940    cpc
# 7678                                                NaN    NaN
# 2939                                        11667201524    cpc
# 2187                                        11667201524    cpc
# 7021                                        11667201524    cpc
#
#                                     userId   source  singular_duplicate  \
# 2252  21f03e02-1bf7-4018-99bb-7264cb804540  adwords               False
# 7648  3a6fe8e6-c150-4c79-b89d-4ff56c48e2b1  adwords               False
# 6225  1e8fdef7-4c8d-4c2a-8df0-a84d953083ac  adwords               False
# 5047  7754ad90-dd5b-47fe-86bf-7ffcb2f01dc7      NaN               False
# 5048  7754ad90-dd5b-47fe-86bf-7ffcb2f01dc7      NaN               False
# ...                                    ...      ...                 ...
# 7183  0e0bb3c7-ea27-4e7f-8f9c-7a6b98364234  adwords               False
# 7678  f163db15-dbda-46bd-9d92-b39ef61ed532      NaN               False
# 2939  6e67f3d0-9d94-42d8-8aae-65f97d4bbb17  adwords               False
# 2187  9900bfac-9317-4b47-a7a8-3f2d38d7d3bc  adwords               False
# 7021  95752db0-81b6-44e9-9069-31bbd2987472  adwords               False
#
#       test_duplicate  row_numbers                  extCode  \
# 2252           False            1                  oficina
# 7648           False            1  articulos-para-el-hogar
# 6225           False            1            bar-cafeteria
# 5047           False            1              restaurante
# 5048           False            1              restaurante
# ...              ...          ...                      ...
# 7183           False            1           tienda-deporte
# 7678           False            1  yoga-pilates-instructor
# 2939           False            1                  oficina
# 2187           False            1                  oficina
# 7021           False            1            bar-cafeteria
#
#                            categorySlug  Comercio   RC  session_count_email  \
# 2252               negocio-inmobiliario       1.0  0.0                    1
# 7648  muebles-decoracion-y-menaje-hogar       1.0  0.0                    1
# 6225          hosteleria-y-restauracion       1.0  0.0                    1
# 5047          hosteleria-y-restauracion       1.0  0.0                    2
# 5048          hosteleria-y-restauracion       1.0  0.0                    1
# ...                                 ...       ...  ...                  ...
# 7183                    deportes-y-ocio       1.0  0.0                    1
# 7678                    deportes-y-ocio       0.0  1.0                    1
# 2939               negocio-inmobiliario       1.0  0.0                    1
# 2187               negocio-inmobiliario       1.0  0.0                    1
# 7021          hosteleria-y-restauracion       1.0  0.0                    1
#
#       session_count_userId         eventTime_ac  \
# 2252                     1  2020-03-19 17:19:55
# 7648                     1  2020-03-19 18:47:35
# 6225                     1  2020-03-19 23:00:34
# 5047                     5  2020-03-19 21:39:56
# 5048                     6                  NaN
# ...                    ...                  ...
# 7183                     1  2020-11-24 06:44:31
# 7678                     1                  NaN
# 2939                     1  2020-11-24 09:19:06
# 2187                     1  2020-11-24 06:52:39
# 7021                     1  2020-11-24 09:38:55
#
#                                                   gclid country  \
# 2252  CjwKCAjwsMzzBRACEiwAx4lLG2l7W3bfpsoxCoLlqbM1Fa...      ES
# 7648  CjwKCAjwsMzzBRACEiwAx4lLG6xiz0GPrIVYIbLrTj7enS...      ES
# 6225                                                NaN      ES
# 5047                                                NaN      ES
# 5048                                                NaN     NaN
# ...                                                 ...     ...
# 7183  EAIaIQobChMIhrj6k8ma7QIVDPlRCh3F-gW5EAAYASACEg...      ES
# 7678                                                NaN     NaN
# 2939  EAIaIQobChMIjd_9q-ya7QIVmO7tCh3GPgBuEAAYASAAEg...      ES
# 2187  CjwKCAiA2O39BRBjEiwApB2IkrXViFw2JBbCWItoo7xPCC...      ES
# 7021  EAIaIQobChMInaC97vCa7QIVE4bVCh3C3AZEEAAYASAAEg...      ES
#
#                        state                  town  zipcode policy_start_date  \
# 2252  Principado de Asturias                Avilés  33402.0        2020-03-19
# 7648               Andalucía  Jerez de la Frontera  11403.0        2020-03-19
# 6225               Andalucía               Sevilla  41006.0        2020-03-19
# 5047     Comunidad de Madrid                Madrid  28022.0        2020-03-19
# 5048                     NaN                   NaN      NaN               NaN
# ...                      ...                   ...      ...               ...
# 7183    Comunidad Valenciana               Teulada   3725.0        2020-11-24
# 7678                     NaN                   NaN      NaN               NaN
# 2939               Andalucía               Granada  18005.0        2020-11-24
# 2187                  Aragón      Mora de Rubielos  44400.0        2020-11-24
# 7021                Cataluña             Martorell   8760.0        2020-11-24
#
#      policy_end_date  floors  goods  surface  inauguration_year  \
# 2252      2021-03-18     1.0    NaN     70.0             1975.0
# 7648      2021-03-18     2.0    NaN     50.0             1989.0
# 6225      2021-03-18     1.0    NaN     45.0             2017.0
# 5047      2021-03-18     1.0    NaN    250.0             1900.0
# 5048             NaN     NaN    NaN      NaN                NaN
# ...              ...     ...    ...      ...                ...
# 7183      2021-11-23     2.0    NaN     20.0             1990.0
# 7678             NaN     NaN    NaN      NaN                NaN
# 2939      2021-11-23     2.0    NaN    200.0             1965.0
# 2187      2021-11-23     2.0    NaN     50.0             2000.0
# 7021      2021-11-23     2.0    NaN     90.0             1988.0
#
#        locationRisk  numLocals  shop_postcalcode  refurbishing_year  \
# 2252      URBAN_HUB        1.0           33402.0                NaN
# 7648      URBAN_HUB        1.0           11403.0                NaN
# 6225      URBAN_HUB        1.0           41006.0                NaN
# 5047      URBAN_HUB        1.0           28022.0             1970.0
# 5048            NaN        NaN               NaN                NaN
# ...             ...        ...               ...                ...
# 7183      URBAN_HUB        1.0            3725.0                NaN
# 7678            NaN        NaN               NaN                NaN
# 2939      URBAN_HUB        1.0           18005.0             2020.0
# 2187      URBAN_HUB        1.0           44400.0                NaN
# 7021  SHOPPING_MALL        1.0            8760.0                NaN
#
#      shop_region                             electronic_protections  \
# 2252       ES-AS                 ["EXTERNAL_ELECTRONIC_PROTECTION"]
# 7648       ES-AN                                                 []
# 6225       ES-AN                 ["INTERNAL_ELECTRONIC_PROTECTION"]
# 5047       ES-MD  ["INTERNAL_ELECTRONIC_PROTECTION","ALARM_CENTER"]
# 5048         NaN                                                NaN
# ...          ...                                                ...
# 7183       ES-VC  ["ALARM_CENTER","INTERNAL_ELECTRONIC_PROTECTION"]
# 7678         NaN                                                NaN
# 2939       ES-AN  ["ALARM_CENTER","INTERNAL_ELECTRONIC_PROTECTION"]
# 2187       ES-AR  ["ALARM_CENTER","INTERNAL_ELECTRONIC_PROTECTION"]
# 7021       ES-CT  ["ALARM_CENTER","INTERNAL_ELECTRONIC_PROTECTION"]
#
#                                        fire_protections  \
# 2252  ["EXTINGUISHER","FIRE_HOSE","FIXED_EXTINGUISHE...
# 7648                                   ["EXTINGUISHER"]
# 6225              ["EXTINGUISHER","FIXED_EXTINGUISHER"]
# 5047    ["EXTINGUISHER","FIRE_DETECTOR","FIRE_STATION"]
# 5048                                                NaN
# ...                                                 ...
# 7183  ["EXTINGUISHER","FIRE_DETECTOR","FIRE_HOSE","F...
# 7678                                                NaN
# 2939  ["EXTINGUISHER","FIRE_DETECTOR","FIRE_HOSE","F...
# 2187  ["EXTINGUISHER","FIRE_DETECTOR","FIRE_HOSE","F...
# 7021  ["EXTINGUISHER","FIRE_DETECTOR","FIRE_HOSE","F...
#
#                 theft_protections watchman_protections      Type  \
# 2252  ["PADLOCK","ARMORED_GLASS"]                   []  Comercio
# 7648                     ["BARS"]                   []  Comercio
# 6225  ["PADLOCK","ARMORED_GLASS"]                   []  Comercio
# 5047           ["PADLOCK","BARS"]                   []  Comercio
# 5048                          NaN                  NaN  Comercio
# ...                           ...                  ...       ...
# 7183           ["BARS","PADLOCK"]                   []  Comercio
# 7678                          NaN                  NaN  Comercio
# 2939           ["BARS","PADLOCK"]                   []  Comercio
# 2187           ["BARS","PADLOCK"]                   []  Comercio
# 7021           ["BARS","PADLOCK"]                   []  Comercio
#
#              eventTime_vg  gross_income  money_invested  \
# 2252  2020-03-19 17:20:54       10000.0             NaN
# 7648  2020-03-19 18:48:56       50000.0             NaN
# 6225  2020-03-19 23:03:02        3000.0         30000.0
# 5047  2020-03-19 21:40:45      200000.0         50000.0
# 5048                  NaN           NaN             NaN
# ...                   ...           ...             ...
# 7183  2020-11-24 06:46:15       30000.0          1000.0
# 7678                  NaN           NaN             NaN
# 2939  2020-11-24 09:19:56      300000.0        165000.0
# 2187                  NaN           NaN             NaN
# 7021  2020-11-24 09:42:22       32000.0         12000.0
#
#       furnitureWithEquipment  merchandise ownership        eventTime_off  \
# 2252                  5000.0       3000.0    TENANT                  NaN
# 7648                  5000.0       5000.0     OWNER                  NaN
# 6225                 15000.0       6000.0    TENANT                  NaN
# 5047                 50000.0       5000.0    TENANT  2020-03-19 21:40:47
# 5048                     NaN          NaN       NaN                  NaN
# ...                      ...          ...       ...                  ...
# 7183                 10000.0      20000.0    TENANT  2020-11-24 06:46:18
# 7678                     NaN          NaN       NaN                  NaN
# 2939                 15000.0       5000.0     OWNER  2020-11-24 09:19:59
# 2187                     NaN          NaN       NaN                  NaN
# 7021                 17000.0       3000.0    TENANT  2020-11-24 09:42:25
#
#       monthlypayment1  premiumPrice1  monthlypayment2  premiumPrice2  \
# 2252              NaN            NaN              NaN            NaN
# 7648              NaN            NaN              NaN            NaN
# 6225              NaN            NaN              NaN            NaN
# 5047           4044.0        48517.0           6463.0        77554.0
# 5048              NaN            NaN              NaN            NaN
# ...               ...            ...              ...            ...
# 7021          Hosteleria y restauracion    0 days 00:00:44  0 days 00:03:27
#
#       time_diff_vg_ff  time_diff_ff_fd time_diff_fd_pm  \
# 2252              NaN              NaN             NaN
# 7648              NaN              NaN             NaN
# 6225              NaN              NaN             NaN
# 5047  0 days 00:00:02  0 days 00:45:04             NaN
# 5048              NaN              NaN             NaN
# ...               ...              ...             ...
# 7183  0 days 00:00:03              NaN             NaN
# 7678              NaN              NaN             NaN
# 2939  0 days 00:00:03  0 days 00:00:54             NaN
# 2187              NaN              NaN             NaN
# 7021  0 days 00:00:03              NaN             NaN
#
#                           city     cityId               region regionId  \
# 2252                 (not set)  (not set)     Balearic Islands    21387
# 7648  El Puerto de Santa Maria    1005445            Andalusia    20269
# 6225                    Madrid    1005493               Madrid  9047045
# 5047                    Madrid    1005493               Madrid  9047045
# 5048                    Madrid    1005493               Madrid  9047045
# ...                        ...        ...                  ...      ...
# 7183                  Valencia    1005545  Valencian Community    21388
# 7678                   Seville    1005421            Andalusia    20269
# 2939                   Granada    1005414            Andalusia    20269
# 2187                  Benidorm    1005403  Valencian Community    21388
# 7021                 Barcelona    1005424            Catalonia    20278
#
#       sessions
# 2252      10.0
# 7648       8.0
# 6225       1.0
# 5047       2.0
# 5048       2.0
# ...        ...
# 7183       1.0
# 7678       1.0
# 2939       1.0
# 2187       1.0
# 7021       1.0
#
# [8062 rows x 106 columns]

# %% [markdown]
# OVERARCHING GOAL: HOW CAN I HELP SALES PRIORITISE LEADS WHO ARE COMING IN
#
# Different categories:
# - RC, Comercio
# - Source
# - Geographical information (zipcode) --> loads --> comunidad automona
# - Sub-categorias --> 300+ --> 50 by using the sales match (correspondece between extCode - Sales categories)
# - Apply k-means using sales data
#
# Continuous variables:
# - Join this with INE data -> barcelona average salary is 30000 --> assign this to the lead
#
# OUTPUT:
# Binary classification of Sales = 1 or = 0
#
# The idea with incoming leads:
# It will sale / good lead
# It will not sale / bad lead

# %%
df2 = data[[ 'Sub_Categoria', 'city', 'RC', 'Comercio', 'sale']]

# %%
df2
# Out:
#                 Sub_Categoria                      city   RC  Comercio  sale
# 2252                  oficina                 (not set)  0.0       1.0     0
# 7648  articulos-para-el-hogar  El Puerto de Santa Maria  0.0       1.0     0
# 6225            bar-cafeteria                    Madrid  0.0       1.0     0
# 5047              restaurante                    Madrid  0.0       1.0     0
# 5048              restaurante                    Madrid  0.0       1.0     0
# ...                       ...                       ...  ...       ...   ...
# 7183           tienda-deporte                  Valencia  0.0       1.0     0
# 7678  yoga-pilates-instructor                   Seville  1.0       0.0     0
# 2939                  oficina                   Granada  0.0       1.0     0
# 2187                  oficina                  Benidorm  0.0       1.0     0
# 7021            bar-cafeteria                 Barcelona  0.0       1.0     0
#
# [8062 rows x 5 columns]

# %%
df2.isnull().sum()
# Out:
# Sub_Categoria      0
# city             599
# RC                99
# Comercio          99
# sale               0
# dtype: int64

# %%
df2.shape[0]
# Out:
# 8062

# %%
df3=df2.dropna()
df3
# Out:
#                 Sub_Categoria                      city   RC  Comercio  sale
# 2252                  oficina                 (not set)  0.0       1.0     0
# 7648  articulos-para-el-hogar  El Puerto de Santa Maria  0.0       1.0     0
# 6225            bar-cafeteria                    Madrid  0.0       1.0     0
# 5047              restaurante                    Madrid  0.0       1.0     0
# 5048              restaurante                    Madrid  0.0       1.0     0
# ...                       ...                       ...  ...       ...   ...
# 7183           tienda-deporte                  Valencia  0.0       1.0     0
# 7678  yoga-pilates-instructor                   Seville  1.0       0.0     0
# 2939                  oficina                   Granada  0.0       1.0     0
# 2187                  oficina                  Benidorm  0.0       1.0     0
# 7021            bar-cafeteria                 Barcelona  0.0       1.0     0
#
# [7373 rows x 5 columns]

# %%
def get_dummies(df, varlist):
    for var in varlist:
        df_slice = pd.get_dummies(df[var])
        df = pd.concat([df.drop(var, axis =1), df_slice], axis =1)
    return df

# %%
categorical_list = ["Sub_Categoria","city"]
X = df2
X = get_dummies(X, categorical_list)

# %%
model = RandomForestClassifier()

# %% [markdown]
# I would suggest the very first Classification Model (random forest, svc):
# - source, region, RC, Comercio target is sale
# - then evaluate the model

# %% [markdown]
# Next step:
# - Add INE data for region
# - Add subcategoria
# - Apply PCA to reduce dimensionality

# %%
categorical_list = ["Sub_Categoria","city"]
X = df3
X = get_dummies(X, categorical_list)

# %%
categorical_list = ["Sub_Categoria","city"]
X = df3.drop(columns='sale')
X = get_dummies(X, categorical_list)
y = df3['sale']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3)
model.fit(X_train, np.ravel(y_train)).score(X_train, np.ravel(y_train)) #adding np.ravel to avoid 1d error
# Out:
# 0.9168765743073047

# %%
model.fit(X_train, np.ravel(y_train)).score(X_test, np.ravel(y_test))
# Out:
# 0.8743218806509946

# %%
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# # Checking Random Forest max_depth plausible

# %%
from sklearn.metrics import accuracy_score
# define lists to collect scores
train_scores, test_scores = list(), list()

# define the tree depths to evaluate
values = [i for i in range(1, 200)]

# evaluate a decision tree for each depth
for i in values:
    # configure the model
    model = RandomForestClassifier(max_depth=i)
    
    # fit model on the training dataset
    model.fit(X_train, np.ravel(y_train))

    # evaluate on the train dataset
    train_yhat = model.predict(X_train)
    train_acc = accuracy_score(np.ravel(y_train), train_yhat)
    train_scores.append(train_acc)

    # evaluate on the test dataset
    test_yhat = model.predict(X_test)
    test_acc = accuracy_score(np.ravel(y_test), test_yhat)
    test_scores.append(test_acc)

    # summarize progress
    print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# Out:
# >1, train: 0.888, test: 0.882
# >2, train: 0.888, test: 0.882
# >3, train: 0.888, test: 0.882
# >4, train: 0.888, test: 0.882
# >5, train: 0.888, test: 0.882
# >6, train: 0.888, test: 0.882
# >7, train: 0.888, test: 0.882
# >8, train: 0.888, test: 0.882
# >9, train: 0.888, test: 0.882
# >10, train: 0.888, test: 0.882
# >11, train: 0.888, test: 0.882
# >12, train: 0.888, test: 0.882
# >13, train: 0.888, test: 0.882
# >14, train: 0.888, test: 0.882
# >15, train: 0.888, test: 0.882
# >16, train: 0.888, test: 0.882
# >17, train: 0.888, test: 0.882
# >186, train: 0.917, test: 0.874
# >187, train: 0.917, test: 0.874
# >188, train: 0.917, test: 0.872
# >189, train: 0.917, test: 0.874
# >190, train: 0.917, test: 0.874
# >191, train: 0.917, test: 0.875
# >192, train: 0.917, test: 0.873
# >193, train: 0.917, test: 0.875
# >194, train: 0.917, test: 0.874
# >195, train: 0.917, test: 0.874
# >196, train: 0.917, test: 0.875
# >197, train: 0.917, test: 0.874
# >198, train: 0.917, test: 0.875
# >199, train: 0.917, test: 0.874

# %%
# plot of train and test scores vs tree depth
plt.plot(values, train_scores, '-o', label='Train')
plt.plot(values, test_scores, '-o', label='Test')
plt.legend()
plt.show()

# %%
model.feature_importances_
# Out:
# array([1.02348880e-02, 1.05947595e-02, 2.21797225e-03, 0.00000000e+00,
#        0.00000000e+00, 2.21181149e-05, 2.15790558e-03, 1.99580908e-03,
#        1.84705632e-03, 8.24071385e-06, 5.07974824e-06, 5.24653698e-03,
#        2.32847921e-03, 3.84258922e-03, 2.05948163e-03, 1.77166211e-03,
#        4.04089503e-04, 5.61235373e-04, 6.63496391e-04, 2.74442463e-04,
#        0.00000000e+00, 4.42140937e-06, 1.26128647e-05, 2.95509253e-08,
#        7.59777604e-06, 1.84296307e-03, 1.75174773e-02, 1.29842862e-04,
#        1.26984084e-04, 2.13256088e-03, 1.45117720e-05, 0.00000000e+00,
#        7.58765595e-03, 6.20913629e-03, 6.56033459e-03, 1.07202805e-03,
#        8.91787106e-04, 1.91784492e-04, 1.29311940e-05, 2.01920369e-05,
#        1.43348786e-03, 3.21866503e-04, 2.80436613e-02, 4.60220866e-05,
#        8.47934342e-06, 4.21229465e-04, 1.14554856e-03, 7.66153321e-05,
#        8.37302850e-05, 0.00000000e+00, 6.62732083e-04, 2.24657726e-03,
#        2.05773180e-04, 7.22715134e-03, 1.44245208e-04, 3.53255145e-05,
#        5.29611639e-04, 8.49622008e-06, 2.33183281e-03, 1.91598638e-04,
#        0.00000000e+00, 1.88736182e-03, 1.11805979e-04, 0.00000000e+00,
#        4.91479740e-05, 1.81644514e-05, 3.50008648e-03, 1.62320349e-03,
#        9.87446726e-06, 3.31837586e-03, 3.27759923e-05, 3.17125326e-03,
#        0.00000000e+00, 1.99287876e-03, 2.18615172e-04, 3.84293888e-03,
#        1.88904864e-05, 9.72613744e-03, 3.27605131e-03, 2.81016233e-06,
#        7.83446183e-06, 3.50121015e-03, 1.75971068e-05, 6.01390281e-04,
#        0.00000000e+00, 1.02216287e-02, 2.94444820e-04, 8.83122919e-05,
#        1.84855400e-05, 3.32418327e-03, 0.00000000e+00, 4.08113522e-03,
#        2.65267455e-05, 7.71770378e-04, 4.93510795e-06, 3.77648626e-03,
#        6.84972328e-03, 2.92634238e-03, 1.17159464e-04, 3.59272076e-03,
#        2.27239750e-04, 4.83035674e-06, 0.00000000e+00, 4.28174435e-06,
#        2.98427154e-04, 4.73143292e-05, 2.45343009e-05, 2.10415994e-04,
#        1.56474483e-04, 6.82862597e-03, 3.84192610e-03, 1.05643163e-05,
#        2.47770137e-03, 5.21223476e-03, 8.81795072e-05, 1.36868400e-02,
#        1.08197349e-03, 0.00000000e+00, 1.19662394e-04, 3.62507172e-04,
#        2.76720825e-03, 7.03657661e-05, 6.87079596e-06, 7.75644360e-05,
#        2.61222856e-03, 2.81099045e-03, 4.72120139e-05, 1.96982323e-05,
#        2.56996949e-04, 4.93477986e-05, 8.97887064e-05, 1.30343072e-03,
#        0.00000000e+00, 6.43832581e-06, 1.50145870e-04, 2.00905722e-07,
#        6.93697843e-03, 2.41770603e-03, 1.52117678e-05, 3.15644985e-06,
#        4.93992165e-05, 7.47824682e-03, 1.21104097e-02, 4.09040537e-03,
#        6.36317784e-04, 3.01651849e-04, 3.18969852e-03, 3.94320173e-05,
#        1.58762572e-04, 2.16581599e-04, 2.97657958e-03, 4.05476484e-03,
#        2.08145922e-03, 4.34940196e-04, 8.36193382e-05, 4.00847360e-04,
#        1.56601924e-04, 1.66067320e-02, 1.07076161e-06, 3.32263064e-05,
#        1.16271355e-04, 7.53728511e-04, 7.50823106e-03, 2.71914357e-04,
#        3.59456878e-04, 0.00000000e+00, 3.35078861e-03, 2.65645207e-03,
#        1.13080243e-04, 1.11926302e-03, 3.46621484e-03, 6.02757423e-04,
#        5.65744501e-05, 0.00000000e+00, 3.01252888e-04, 1.68739032e-03,
#        4.02391111e-05, 6.43338522e-03, 2.20658046e-04, 1.80690948e-02,
#        1.11637041e-02, 3.16989303e-03, 0.00000000e+00, 6.94102920e-03,
#        2.46212017e-05, 1.66531111e-04, 2.26080282e-04, 1.07564295e-07,
#        1.71984704e-05, 2.37290400e-03, 3.15131198e-04, 1.37772139e-04,
#        2.68233454e-03, 2.66253450e-03, 5.77263275e-05, 1.14303389e-02])

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [10,12,15,17],
    'max_features': [5], #For classification a good default is: m = sqrtp
    'n_estimators': [100,300,500], 
    'criterion': ['gini', 'entropy']
}

# %%
model_sel = GridSearchCV(model,param_grid)

# %%
model_sel.fit(X_train, np.ravel(y_train))
# Out:
# GridSearchCV(estimator=RandomForestClassifier(max_depth=199),
#              param_grid={'bootstrap': [True], 'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 12, 15, 17], 'max_features': [5],
#                          'n_estimators': [100, 300, 500]})

# %%
model_sel.best_estimator_.score(X_test, y_test)
# Out:
# 0.8824593128390597

# %%
model_sel.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'max_depth': 10,
#  'max_features': 5,
#  'n_estimators': 100}

# %%
y_pred = model_sel.predict(X_test)

# %%
print(classification_report(y_test, y_pred ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      1952
#            1       0.00      0.00      0.00       260
#
#     accuracy                           0.88      2212
#    macro avg       0.44      0.50      0.47      2212
# weighted avg       0.78      0.88      0.83      2212
# C:\Users\Álvaro\anaconda3.1\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df["sale"].value_counts()
# Out:
# 0    7157
# 1     905
# Name: sale, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-3af27e912b95> in <module>
# ----> 1 plot_feature_importance(rf_model.feature_importances_,train.columns,'RANDOM FOREST')
#
# NameError: name 'plot_feature_importance' is not defined
